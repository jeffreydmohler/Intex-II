# %%
# Data Setup

# Choose which columns you want dropped from the model. This is a list!

# Columns I chose to delete:
#    comments            too many null values in the column
#    photo_url           not applicable to the experiment it's just a url for the picture
#    collected_date      Dates are dependent on unpredictable events happening in the world. We will get rid of this for now
#    created_at          same as above
#    updates_author      This is a name. Not useful for prediction
dropcols = ['comments', 'photo_url', 'collected_date', 'created_at', 'updates_author', 'Column1']

# Choose your data set and get the data imported
#df = import_data('updates', dropcols)

# Run your unistats summary
uniStats(df)

# Because none of these files are numeric types (not counting id's), we will not adjust for skewness with any of these files
# Out:
#                     DataType  Count Null Count Unique Values  \
# updates_text          object  37368          0          1712
# updates_author_type   object  37368          0             3
# update_id              int64  37368          0          1722
# campaign_id            int64  37368          0           736
#
#                                             Mode         Mean      STD  \
# updates_text         Custom design more to come.            -        -
# updates_author_type                    ORGANIZER            -        -
# update_id                               24145104  2.41396e+07  28852.2
# campaign_id                             46073696  4.62315e+07   296268
#
#                           Min          25%       Median          75%  \
# updates_text                -            -            -            -
# updates_author_type         -            -            -            -
# update_id            23456838  2.41369e+07  2.41444e+07  2.41525e+07
# campaign_id          17242942  4.61067e+07  4.62051e+07  4.63514e+07
#
#                           Max     Skew     Kurt
# updates_text                -        -        -
# updates_author_type         -        -        -
# update_id            24160136 -7.67312  98.6246
# campaign_id          47012554 -33.7156  2955.22

# %%
# Let's change our data types
df['update_id'] = df['update_id'].astype(int)
df['updates_text'] = df['campaign_id'].astype(str)
df['campaign_id'] = df['campaign_id'].astype(int)
df['updates_author_type'] = df['updates_author_type'].astype(str)

# %%
# Now, we need to take out the line breaks
for row in df['updates_text']:
    df['updates_text'].replace('\n', '')

# %%
# Function to import your data. This will be called throughout the worksheet
def import_data(data,drop):
    # Import packages
    import pandas as pd
    
    data = data
    
    df = pd.read_csv('C:/Analytics/Data/' + data + '.csv')
    
    # Clean updates_author_type row. We will fill this with "Organizer" as that is the mode value
    df.updates_author_type.fillna('ORGANIZER', inplace=True)
    
    # Remove rows that don't involve 2020
    # Remove rows that don't involve 2020
    year = df.created_at.str[:4]
    df['ld_year'] = year 
    df.drop(df[df['ld_year'] != '2020'].index, inplace=True)
    df.drop(columns=['ld_year'], inplace=True)
            
    # Remove rows where the author's name has corona
    # NOTE: I am having a hard time iterrating over the text to check if that is also there. However, there are only 108 in this file,
    #       So I will just delete the 108 rows. That's a pretty insignificant number of rows
    for row in df.iterrows():
        if ('corona' in row[1][6] or 'Corona' in row[1][6]):
            #if not 'coronaI' in row[1][8] or 'Corona' in row[1][8]:
            #    corona_count +=1
            df.drop([row[0]], inplace=True)
    
    for i in drop:
        df.drop(columns=[i], inplace=True)
        
    # This will drop the 198 null rows in the updates_text file
    df.dropna(axis = 0, inplace=True)
        
    return df

# %%
def uniStats(df):
    # Import packages
    import pandas as pd
    pd.set_option('display.max_rows', 100)
    pd.set_option('display.max_columns', 100)

    # Build the data frame
    new_df = pd.DataFrame(columns = ['DataType', 'Count', 'Null Count', 'Unique Values', 'Mode', 
                                     'Mean', 'STD', 'Min', '25%', 'Median', '75%', 'Max', 'Skew', 'Kurt'])

    # Build the data frame:
    for col in df:
        # Build data frame for numeric stats:
        if pd.api.types.is_numeric_dtype(df[col]):
            new_df.loc[col] = [df[col].dtype, df[col].count(), df[col].isnull().sum(), df[col].nunique(), 
                               df[col].mode().values[0], df[col].mean(), df[col].std(), df[col].min(), 
                               df[col].quantile(.25), df[col].median(), df[col].quantile(.75), df[col].max(), 
                               df[col].skew(), df[col].kurt()]
        # Build data frame for categorical stats:
        else:
            new_df.loc[col] = [df[col].dtype, df[col].count(), df[col].isnull().sum(), df[col].nunique(), 
                               df[col].mode().values[0], '-', '-', '-', '-', '-', '-', '-', '-', '-']

    return new_df.sort_values(by=['DataType', 'Skew', 'Unique Values'], ascending=False)

# %%
# Export to a CSV
df.to_csv(r'C:\Analytics\data\updates_clean.csv', index = False)

# %%
df.head(100)
# Out:
#     update_id campaign_id updates_author_type  \
# 202  23456838    43814064           ORGANIZER
# 204  23496568    44507882           ORGANIZER
# 205  23501090    44507882           ORGANIZER
# 206  23506548    42707740           ORGANIZER
# 209  23545636    44507882           ORGANIZER
# 210  23639824    44110880           ORGANIZER
# 211  23641718    44967662           ORGANIZER
# 215  23657124    44998668         TEAM_MEMBER
# 217  23661206    44996060           ORGANIZER
# 218  23669512    44996060           ORGANIZER
# 219  23669558    44996060           ORGANIZER
# 220  23675074    44998668           ORGANIZER
# 222  23686476    45126576           ORGANIZER
# 223  23687998    45053686           ORGANIZER
# 224  23688218    44998668           ORGANIZER
# 225  23694320    45158884           ORGANIZER
# 226  23696618    45138932           ORGANIZER
# 230  23701866    44958914           ORGANIZER
# 232  23707724    44996060           ORGANIZER
# 234  23715126    45195598           ORGANIZER
# 235  23722820    45047014           ORGANIZER
# 236  23722992    45180724         TEAM_MEMBER
# 237  23728564    45151772           ORGANIZER
# 239  23737602    45173660           ORGANIZER
# 241  23746022    44998668           ORGANIZER
# 242  23746036    44998668           ORGANIZER
# 243  23746038    44998668           ORGANIZER
# 244  23746324    45173660           ORGANIZER
# 246  23756222    45265176           ORGANIZER
# 247  23756860    45340010           ORGANIZER
# 248  23760754    44516468           ORGANIZER
# 249  23761478    44998668           ORGANIZER
# 250  23761504    44998668           ORGANIZER
# 251  23761784    45047014           ORGANIZER
# 252  23761972    45173660           ORGANIZER
# 253  23769546    45173660           ORGANIZER
# 254  23772792    45126576           ORGANIZER
# 255  23773678    45280540           ORGANIZER
# 256  23774080    45280540           ORGANIZER
# 257  23774370    45280540           ORGANIZER
# 258  23776844    45173660           ORGANIZER
# 259  23777930    45391426           ORGANIZER
# 260  23778020    45405626           ORGANIZER
# 262  23781814    45280540           ORGANIZER
# 265  23783900    45391426           ORGANIZER
# 266  23789236    45280540           ORGANIZER
# 267  23790104    45405626           ORGANIZER
# 268  23793408    45068676           ORGANIZER
# 269  23794764    45047014           ORGANIZER
# 270  23796190    45312326           ORGANIZER
# 271  23802466    45421858           ORGANIZER
# 273  23813110    45391426           ORGANIZER
# 274  23813222    45391426           ORGANIZER
# 275  23813876    45280540           ORGANIZER
# 276  23815132    45047014           ORGANIZER
# 277  23815264    45457980           ORGANIZER
# 278  23819874    45273774           ORGANIZER
# 280  23820578    45053686           ORGANIZER
# 281  23823392    45421858           ORGANIZER
# 282  23824656    45507028           ORGANIZER
# 283  23824664    45507028           ORGANIZER
# 284  23824752    45507028           ORGANIZER
# 285  23824768    45405626           ORGANIZER
# 286  23824806    45405626           ORGANIZER
# 287  23826170    45273774           ORGANIZER
# 288  23829812    45280540           ORGANIZER
# 289  23830178    45507028           ORGANIZER
# 291  23830738    45501212           ORGANIZER
# 293  23836100    45329902           ORGANIZER
# 294  23836124    45329902           ORGANIZER
# 295  23839604    45507028           ORGANIZER
# 296  23840886    45047014           ORGANIZER
# 297  23846130    45058810           ORGANIZER
# 298  23846160    45058810           ORGANIZER
# 299  23847402    45507028           ORGANIZER
# 302  23851476    45604410           ORGANIZER
# 303  23852336    45203128           ORGANIZER
# 304  23852670    45173660           ORGANIZER
# 305  23854566    45143058           ORGANIZER
# 306  23855192    45391426           ORGANIZER
# 307  23856550    45507028           ORGANIZER
# 308  23862162    45025362           ORGANIZER
# 309  23873252    45143058           ORGANIZER
# 310  23874394    45405626           ORGANIZER
# 311  23874400    45405626           ORGANIZER
# 313  23880082    45047014           ORGANIZER
# 314  23881804    45405626           ORGANIZER
# 315  23873160    45507028           ORGANIZER
# 316  23887546    45608948           ORGANIZER
# 317  23887920    45273774           ORGANIZER
# 318  23890406    45391426           ORGANIZER
# 320  23901172    45758008           ORGANIZER
# 321  23905706    45204444           ORGANIZER
# 322  23906806    45611390           ORGANIZER
# 323  23908796    45758008           ORGANIZER
# 324  23914290    45265176           ORGANIZER
# 325  23914544    45047014           ORGANIZER
# 327  23917016    45143058           ORGANIZER
# 328  23920840    45827358           ORGANIZER
# 329  23920892    45827358           ORGANIZER
#
#                                           updates_text
# 202  Since I last updated the wooden fence between ...
# 204                               #TodossomosMiguelito
# 205                          Numero de Cuenta en Pesos
# 206  We still need to raise $7000 dollars for healt...
# 209  We thank you All for your prayers, donations a...
# 210            Our Young Mathematicians Busy at Work!!
# 211                           Please we need your help
# 215            These are our orders and confirmations.
# 217  Dear friends,\n\nWe have located few places (o...
# 218  Today we have purchased 1304 pcs of protective...
# 219  Officially spend for the 1304 pcs of protectiv...
# 220  The fist goggles delivery Newyork!We will ship...
# 222  Latest Update, 30.01.2020:\n\nWe have now acqu...
# 223  Thanks to all of your help, we have already re...
# 224                                   We packing today
# 225                      Let&#039;s fight corona virus
# 226  Thank you everyone for the support, we have ra...
# 230  We have started laying the wood flooring and m...
# 232                   The stuffs arrived the hospital!
# 234  Overnight there is newly added 2829 patients, ...
# 235  2/3 Update:\n\nThanks to the effort of our vol...
# 236  We have received $911 by far. Your contributio...
# 237     Thanks Air China! More masks are on their way!
# 239  Just shipping out 3000 masks. Donated from one...
# 241  We send all purchased masks and goggles to China.
# 242  We send all purchased masks and goggles to China.
# 243  We send all purchased masks and goggles to China.
# 244  Doctor who sounded alarm on coronavirus dies\n...
# 246  While international chinese communities are fa...
# 247                                Corona Virus Spread
# 248  GREAT NEWS EVERYONE... Baby Boy finally got ap...
# 249    1000pcs goggles    total:$2920.41\n540pcs masks
# 250  We received:$2745.52(after fee).\nwe paid:$292...
# 251  2/8 Update:\n\nOur order of 40 Dupont Tychem 2...
# 252  Today we were asked to find children&#039;s me...
# 253  Our hearts go out to all the victims  as well ...
# 254  dear friends and donors, here is our latest up...
# 255  Updates: \nOn Feb. 3rd, we saw the news report...
# 256  During the fundraising period, our alumni, fri...
# 257  经过志愿者们夜以继日的奔波和努力，第一批援助物资已经完成筹备，近日内将运往河南，紧急支援奋战...
# 258  These masks from Japan, donated to China. They...
# 259  We have collected 40 boxes so far, more will c...
# 260                                              #武汉加油
# 262  Dear Donors, \n\nMillions thanks for your gene...
# 265  First parcel is packed and to be sent to Hong ...
# 266  非常感谢许许多多台前幕后的爱心人士和机构慷慨捐助，并大力支持我们协助河南抗击新型冠状病毒疫情...
# 267                                               洪山广场
# 268  Due to the fact that few masks can be found ik...
# 269  2/12 Update:\n\nFor full disclosure, multiple ...
# 270  First delivery is out! Sending 300 n95 masks w...
# 271  Quick update for those of you who have been as...
# 273  Another shipment of 2600 surgical masks  poste...
# 274  The short of PPE supply from one of the major ...
# 275  各位捐助者，\n\n您的善款所购买的医疗救援物资已经于2月14日抵达北京首都机场，目前正在运...
# 276  2/15 Update:\n\nWe have confirmation on our ye...
# 277  Thank you for everyone who has donated! Yester...
# 278  Thanks everyone for your donation and sharing!...
# 280  With all of your help, we were able to send 75...
# 281  Please continue to pray for my beautiful niece...
# 282  Confirmed case 70,640 and deaths 1,772 as of 0...
# 283  Countless medical teams from all over China ar...
# 284  The number of Coronavirus cases is growing glo...
# 285                       Baotong Temple and City view
# 286              Let’s fight! We are one, Wuhan Jiayou
# 287  A very kind gentleman helped me getting this a...
# 288  Dear donors and supporters, \n\nIt&#039;s been...
# 289  People of all faiths praying at the Western Wa...
# 291  Emilio Avil Corona, also known as Elmo, Leo, G...
# 293                   Gloves are boxed and ready to go
# 294                  A photo of the plant in Colebrook
# 295  After wearing masks and full coverage for too ...
# 296  2/18 Update:\n\nDear donors, with people in no...
# 297  Thank you all for the donations! We have our f...
# 298             Official documents to verify purchase.
# 299  The children of New York have started to donat...
# 302  谢谢大家，我们总共用了15个小时，筹集了1000美元的善款。我们跟北京协和医院联系后，本批善...
# 303  Just in! Thanks to your donations, we have ord...
# 304  over 2,100 people have died so far and 75000 i...
# 305  Mission Accomplished and moving closer to our ...
# 306  Shipment to be sent tomorrow, including face v...
# 307  Front line heroes who lost their life to prote...
# 308  We did it! 8500 units of protective coverall f...
# 309  We are thankful for endorsements from our Chin...
# 310  The suits arrived today at the hospital!!! The...
# 311  First things arrived and masks on their way! 武汉加油
# 313  2/23 Update:\n\nAnd it&#039;s a wrap for the d...
# 314  The masks arrived today!! This is the proof th...
# 315  Thank you Bluebird Estates for allowing me to ...
# 316  To all my donors, I just want to give you guys...
# 317  Masks on the way to New York! One step closer ...
# 318  Note from the Hong Kong Medical Association ( ...
# 320  The US needs a total of 2.5 billion to get the...
# 321  Dear Donors, \n\nThank you very much for your ...
# 322  We made it home!!!! Now... we have to do the t...
# 323  The first thing everyone should invest in for ...
# 324  1st batch of masks Received! Will start distri...
# 325  2/27 Update:\n\nOur 100K worth of respirators ...
# 327  ***UPDATE*** our first shipment of 5 large pac...
# 328  History of corona virus \nGraphics comparison ...
# 329  ❗️ İMPORTANT❗️ The lethality rate of COVID-19 ...
